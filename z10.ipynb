# %%
class car:
    def __init__(self,brand,model,year):
        self.brand=brand
        self.model=model
        self.year=year

    def display_info(self):
        print(f"{self.year} {self.brand} {self.model}")


car1=car("toyota","coralla",2020)
car1.display_info()
# Out:
#   Cell In[5], line 8
#     print(f"{self.year} {self.brand} {self.model})
#           ^
# SyntaxError: unterminated f-string literal (detected at line 8)
