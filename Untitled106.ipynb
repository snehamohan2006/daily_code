# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None

first=node(10)
second=node(20)
third=node(30)
fourth=node(40)
fifth=node(50)


first.next=second
second.next=third
third.next=fourth
fourth.next=fifth

head=first

current=head
while current:
    print(current.data)
    current=current.next

previous=None
print("original linked list:")
# Out:
# 10
# 20
# 30
# 40
# 50
