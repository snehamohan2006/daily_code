# %%
i=1
while i<6:
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i=1
while i<6:
    print(i)
    if i==3:
        break
    i+=1
# Out:
# 1
# 2
# 3

# %%
i=1
while i<6:
    print(i)
    i+=1
