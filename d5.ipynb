# %%
def sneha():
    return "I am good girl"

print(sneha())
# Out:
# I am good girl

# %%
def sneha():
    print("I  am sneha I can prove them wrong")

message=sneha()
print(message)
# Out:
# I  am sneha I can prove them wrong
# None

# %%
r=range(10)
print(r[2])
print(r[:3])
# Out:
# 2
# range(0, 3)

# %%
r=range(0,10,2)
prin
