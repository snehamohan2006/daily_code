# %%
def add(a,b):
    print(a+b)

add(10,15)
# Out:
# 25

# %%
def biggest(a,b):
    if(a>b):
        print("yes a is biggest")
    else:
        print("no a is not biggest")

biggest(9,90)
# Out:
# no a is not biggest
