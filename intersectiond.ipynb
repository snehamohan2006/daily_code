# %%
x={"cat","dog","bird"}
y={"cow","goat"}
x.intersection_update(y)
print(x)
# Out:
# {'cat'}

# %%
x={"cat","dog","bird"}
y={"cow","goat","cat"}
z=x.difference(y)
print(z)
# Out:
# {'dog', 'bird'}

# %%
x={"cat","dog","bird"}
y={"cow","goat","cat"}
z=x-y
print(z)
# Out:
# {'dog', 'bird'}
