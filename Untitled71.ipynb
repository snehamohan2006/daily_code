# %%
company=["microsoft","google","infosys","IBM"]
company.insert(2,"DELL")
print(company)
# Out:
# ['microsoft', 'google', 'DELL', 'infosys', 'IBM']

# %%
numbers=[10,20,30,40,50,60]
numbers.append(70)
print(numbers)
numbers.insert(0,5)
print(numbers)
numbers[1]=25
print(numbers)
numbers[0]
numbers.remove(20)
print(numbers)
print(len(numbers))
for number in numbers:
    print(number)
# Out:
# [10, 20, 30, 40, 50, 60, 70]
# [5, 10, 20, 30, 40, 50, 60, 70]
# [5, 25, 20, 30, 40, 50, 60, 70]
# [5, 25, 30, 40, 50, 60, 70]
# 7
# 5
# 25
# 30
# 40
# 50
# 60
# 70
