# %%
fruits=["apple","banana","mango"]
newlist=[x for x in fruits if x!="apple"]
print(newlist)
# Out:
# ['banana', 'mango']

# %%
fruits=["mango","banana","apple","bringjal"]
newlist=[x for x in fruits]
print(newlist)
# Out:
# ['mango', 'banana', 'apple', 'bringjal']

# %%
newlist=[x for x range in(10)]
print(newlist)
# Out:
#   Cell In[11], line 1
#     newlist=[x for x range in(10)]
#                    ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
