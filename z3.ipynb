# %%
class myclass:
    x=5
print(myclass)
# Out:
# <class '__main__.myclass'>

# %%
class myclass:
    x=5

p1=myclass()
print(p1.x)
# Out:
# 5

# %%
class myclass:
    x=5

p1=myclass()
p2=myclass()
p3=myclass()
print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5
