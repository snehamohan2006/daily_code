# %%
a=["sneha","mohan","aksh"]
b=["suma","lithu","kanth"]
for x in a:
    for y in b:
        print(x,y)
# Out:
# sneha suma
# sneha lithu
# sneha kanth
# mohan suma
# mohan lithu
# mohan kanth
# aksh suma
# aksh lithu
# aksh kanth

# %%
for x in range(6):
    if x==3: 
        break
    print(x)
