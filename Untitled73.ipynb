# %%
fam=("Saraswathi","Lokesh","suma","Akshatha","sneha","mohan")
print(fam[2])
print(fam)
print(len(fam))
# Out:
# suma
# ('Saraswathi', 'Lokesh', 'suma', 'Akshatha', 'sneha', 'mohan')
# 6

# %%
fam=("Saraswathi","Lokesh","suma","Akshatha","sneha","mohan")
fam[4]="Lithinksha"
print(fam)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 fam=("Saraswathi","Lokesh","suma","Akshatha","sneha","mohan")
# ----> 2 fam[4]="Lithinksha"
#       3 print(fam)
#
# TypeError: 'tuple' object does not support item assignment

# %%
num=(1,2,3,4,5,6)
print(num.count(5))
print(num.index(3))
# Out:
# 1
# 2
