# %%
a="hello world"
print(a.upper())
# Out:
# HELLO WORLD

# %%
a="HELOO WORL   D"
print(a.lower())
# Out:
# heloo worl   d

# %%
#strip
a="he  llo     world"
print(a.strip())
# Out:
# he  llo     world
