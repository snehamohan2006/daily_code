# %%
num={10,20,10,30,40,30}
print(num)
# Out:
# {40, 10, 20, 30}

# %%
fam={"suma","Akshatha","Sneha","mohan"}
fam.add("Lithiksha")
print(fam)
num.remove("sneha")
print(num)
# Out:
# {'Lithiksha', 'mohan', 'suma', 'Akshatha', 'Sneha'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 4
#       2 fam.add("Lithiksha")
#       3 print(fam)
# ----> 4 num.remove("sneha")
#       5 print(num)
#
# KeyError: 'sneha'
