# %%
import datetime
x=datetime.datetime.now()
print(x.year)
print(x.strftime("%A"))
# Out:
# 2026
# Wednesday

# %%
import datetime
x=datetime.datetime(2020,5,7)
print(x)
# Out:
# 2020-05-07 00:00:00

# %%
import datetime

x = datetime.datetime(2018, 6, 1)

print(x.strftime("%B"))
# Out:
# June
