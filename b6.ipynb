# %%
class person:
    def __init__(self,fname,lname):
        self.firstname=fname
        self.lastname=lname

    def printname(self):
        print(self.firstname,self.lastname)

class student(person):
    def __init__(self,fname,lname):
        person.__init__(fname,lname)
        self.graduationyear=year
        

x=student("sneha","al",2019)
print(x.graduationyear)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 15
#      11         person.__init__(fname,lname)
#      12         self.graduationyear=year
# ---> 15 x=student("sneha","al",2019)
#      16 print(x.graduationyear)
#
# TypeError: student.__init__() takes 3 positional arguments but 4 were given
