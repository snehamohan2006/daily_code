# %%
x=min(5,10,15)
y=max(5,10,15)
print(x)
print(y)
# Out:
# 5
# 15

# %%
x=abs(-7.25)
print(x)
# Out:
# 7.25

# %%
x=pow(4,3)
print(x)
# Out:
# 64

# %%
import math

x=math.sqrt(64)
print(x)
# Out:
# 8.0
