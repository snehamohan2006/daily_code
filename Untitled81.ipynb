# %%
stack=["A","B","C"]
print(stack[-1])
# Out:
# C

# %%
stack=[]
stack.append("A")
stack.append("B")
stack.append("C")
print(stack[-1])
print(stack)
# Out:
# C
# ['A', 'B', 'C']

# %%
stack=[]
if len(stack)==0:
    print("stack is empty")
# Out:
# stack is empty

# %%
stack=[]
if not stack:
    print("stack is empty")
# Out:
# stack is empty

# %%
stack=[]
stack.append("a")
stack.append("c")
stack.append("b")

stack.pop()
stack.pop()
stack.pop()

if not stack:
    print("stack is empty")
# Out:
# stack is empty
