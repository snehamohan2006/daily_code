# %%
s1={"cat","dog","bird","cow","goat"}
s2={"man","woman","lion","tiger"}
s3=s1.union(s2)
print(s3)
# Out:
# {'tiger', 'goat', 'man', 'lion', 'bird', 'cat', 'woman', 'cow', 'dog'}

# %%
s1={"cat","dog","bird","cow","goat"}
s2={"man","woman","lion","tiger"}
s3=s1 | s2
print(s3)
# Out:
# {'tiger', 'goat', 'man', 'lion', 'bird', 'cat', 'woman', 'cow', 'dog'}

# %%
s1={"cat","dog","bird"}
s2={"cow","goat"}
s3={"man","woman"}
s4={"lion","tiger"}
s5=s1.union(s1,s2,s3,s4)
print(s5)
# Out:
# {'tiger', 'goat', 'man', 'lion', 'bird', 'cat', 'woman', 'cow', 'dog'}

# %%
s1={"cat","dog","bird"}
s2={"cow","goat"}
s3={"man","woman"}
s4={"lion","tiger"}
s5=s1|s2|s3|s4
print(s5)
# Out:
# {'tiger', 'goat', 'man', 'lion', 'bird', 'cat', 'woman', 'cow', 'dog'}

# %%
x={"cat","dog","bird"}
y={"cow","goat"}
z=x.union(y)
print(z)
# Out:
# {'goat', 'cat', 'cow', 'dog', 'bird'}

# %%
x={"cat","dog","bird"}
y={"cow","goat","cat"}
z=x.intersection(y)
print(z)
# Out:
# {'cat'}

# %%
x={"cat","dog","bird"}
y={"cow","goat"}
z=x &
