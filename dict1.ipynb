# %%
fam={
    "Father":"Lokesh",
    "Mother":"Saraswathi",
    "Elderone":"suma",
    "middleone":"akshatha",
    "youngerone":"sneha",
    "lastone":"Mohan"
}
print(fam)
print(fam["Mother"])
# Out:
# {'Father': 'Lokesh', 'Mother': 'Saraswathi', 'Elderone': 'suma', 'middleone': 'akshatha', 'youngerone': 'sneha', 'lastone': 'Mohan'}
# Saraswathi

# %%
fam={
    "Father":"Lokesh",
    "Mother":"Saraswathi",
    "Elderone":"suma",
    "middleone":"akshatha",
    "youngerone":"sneha",
    "lastone":"Mohan"
}
print(len(fam))
# Out:
# 6

# %%
fam={
    "Father":"Lokesh",
    "Mother":"Saraswathi",
    "Elderone":"suma",
    "middleone":"akshatha",
    "youngerone":"sneha",
    "lastone":"Mohan"
}
print(type(fam))
# Out:
# <class 'dict'>

# %%
fam=dict(name="lokesh",age=56,work="farmer")
print(fam)
# Out:
# {'name': 'lokesh', 'age': 56, 'work': 'farmer'}
