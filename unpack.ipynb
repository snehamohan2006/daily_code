# %%
us=("sneha","bhavana","aishu","kousalya")
(green,red,yllow,black)=us
print(green)
print(red)
print(yllow)
print(black)
# Out:
# sneha
# bhavana
# aishu
# kousalya

# %%
us=("sneha","bhavana","aishu","kousalya")
(green,red,*yellow)=us
print(green)
print(red)
print(yellow)
# Out:
# sneha
# bhavana
# ['aishu', 'kousalya']
