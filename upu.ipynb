# %%
x=("mohan","suma","akshatha","sneha")
y=list(x)
y[1]="kiwi"
x=tuple(y)
print(x)
# Out:
# ('mohan', 'kiwi', 'akshatha', 'sneha')

# %%
bond=("mohan","suma","akshatha")
m=list(bond)
m.append("sneha")
bond=tuple(m)
print(bond)
# Out:
# ('mohan', 'suma', 'akshatha', 'sneha')

# %%
bond=("mohan","suma","akshatha")
y="sneha"
bond
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 bond=("mohan","suma","akshatha")
#       2 y="sneha"
# ----> 3 y+=bond
#       4 print(c)
#
# TypeError: can only concatenate str (not "tuple") to str
