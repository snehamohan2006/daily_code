# %%
#arithmetic operation
x=6
y=5
print(x+y) #addition
print(x-y) #sub
print(x*y) #multiplication
print(x//y) #divide single value
print(x/y) #divide floating value
print(x%y) #reminder
print(x**y) #double multiplication
# Out:
# 11
# 1
# 30
# 1
# 1.2
# 1
# 7776
