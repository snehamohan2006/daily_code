# %%
toys=["car","doll","camera","teddy"]
for toy in toys:
    print(toy)
# Out:
# car
# doll
# camera
# teddy

# %%
toys=["car","doll","camera","teddy"]
print(toys)
print(toys[0])
print(toys[1])
print(toys[2])
toys.append("cap")
print(toys)
toys.remove("car")
print(toys)
for toy in toys:
    print(toy)
# Out:
# ['car', 'doll', 'camera', 'teddy']
# car
# doll
# camera
# ['car', 'doll', 'camera', 'teddy', 'cap']
# ['doll', 'camera', 'teddy', 'cap']
# doll
# camera
# teddy
# cap

# %%
fam=["akshtaha","suma","sneha","mohan"]
print(fam)
print(fam[1])
print(fam[2])
fam.append("lithiksha")
print(fam)
fam.remove("sneha
