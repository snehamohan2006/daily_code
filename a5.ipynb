# %%
class person:
    def __init(self,name,age):
        self.name=name
        self.age=age

p1=person("sneha",20)

print(p1.name)
print(p1.age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3         self.name=name
#       4         self.age=age
# ----> 6 p1=person("sneha",20)
#       8 print(p1.name)
#       9 print(p1.age)
#
# TypeError: person() takes no arguments
