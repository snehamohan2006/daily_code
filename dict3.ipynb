# %%
d={
    "maa":"saru",
    "paa":"loki",
    "sis":"suma",
    "bro":"moha"
}
d["sis"]="akshatha"
print(d)
# Out:
# {'maa': 'saru', 'paa': 'loki', 'sis': 'akshatha', 'bro': 'moha'}

# %%
d={
    "maa":"saru",
    "paa":"loki",
    "sis":"suma",
    "bro":"moha"
}
d.update({"youngerone":"sneha"})
print(d)
# Out:
# {'maa': 'saru', 'paa': 'loki', 'sis': 'suma', 'bro': 'moha', 'youngerone': 'sneha'}
