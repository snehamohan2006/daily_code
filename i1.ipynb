# %%
str="banana"
myit=iter(str)

print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# b
# a
# n
# a
# n
# a

# %%
str="banana"
for x in str:
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
tuple=("sneha","akshatha","sneha")
for x in tuple:
    print(x)
# Out:
# sneha
# akshatha
# sneha

# %%
class sneha:
    def __iter__(self):
        self.a=1
        return self

    def __next__(self):
        x=self.a
        self.a+=1
        return x

myclass=Sneha()
myiter=iter(myclass)

print(next(myiter))
# Out:
#   Cell In[9], line 3
#
#     ^
# SyntaxError: incomplete input
