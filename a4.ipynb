# %%
car=["lamborgini","bmw","Rollsroyce","Tesla"]
print(car)
# Out:
# ['lamborgini', 'bmw', 'Rollsroyce', 'Tesla']

# %%
car=["lamborgini","bmw","Rollsroyce","Tesla"]
print(car[0])
# Out:
# lamborgini

# %%
car=["lamborgini","bmw","Rollsroyce","Tesla"]
print(car[1])
# Out:
# bmw

# %%
car=["lamborgini","bmw","Rollsroyce","Tesla"]
print(car[2])
# Out:
# Rollsroyce

# %%
car=["lamborgini","bmw","Rollsroyce","Tesla"]
print(car[3car=["lamborgini","bmw","Rollsroyce","Tesla"]
print(car[0])])
