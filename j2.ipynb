# %%
import json

print(json.dumps({"name":"sneha","age":20,"edu":"cse"}))
print(json.dumps(["apple","banana"]))
print(json.dumps(("apple","banana")))
print(json.dumps((23)))
print(json.dumps((31.76)))
print(json.dumps((True)))
print(json.dumps((False)))
print
# Out:
# {"name": "sneha", "age": 20, "edu": "cse"}
# ["apple", "banana"]
# ["apple", "banana"]
# 23
