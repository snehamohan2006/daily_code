# %%
student={
    "Name":"Sneha",
    "age":20,
    "College":"DSATM"
}
for key in student:
    print(key)
# Out:
# Name
# age
# College

# %%
student={
    "Name":"Sneha",
    "age":20,
    "College":"DSATM"
}
for value in student:
    print(value)
# Out:
# Name
# age
# College

# %%
student={
    "Name":"Sneha",
    "age":20,
    "College":"DSATM"
}
for key in student:
    print(student[key])
# Out:
# Sneha
# 20
# DSATM

# %%
student={
    "Name":"Sneha",
    "age":20,
    "College":"DSATM"
}
for key in student:
    print(key, student[key])
# Out:
# Name Sneha
# age 20
# College DSATM

# %%
stack=[]

stack.append("A")
stack.append("B")
stack.append("c")
print(stack)
stack.pop()
print(stack)
# Out:
# ['A', 'B', 'c']
# ['A', 'B']
