# %%
#my learnings
#print
print("Hello world")
# Out:
# Hello world

# %%
# oprations
print(1+2)
print(2-1)
print(3*1)
print(3//1)
print(3/1)
# Out:
# 3
# 1
# 3
# 3
# 3.0

# %%
#data types
y=8
print(type(y))
x=3.0
print(type(x))
n="sneha"
print(type(n))
i=True
print(type(i))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
#conditional statement if and else
n=int(input("enter the integer:"))
if n>50:
    print("n is greater")
else:
    print("n is lesser")
# Out:
# enter the integer: 23
# n is lesser

# %%
#age
age=intinput("enter your age:")
if age>=18:
    print("the person is eligible to vote")
else:
    print("The person is not eligible to vote")
# Out:
# enter your age: 18
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 #age
#       2 age=input("enter your age:")
# ----> 3 if age>=18:
#       4     print("the person is eligible to vote")
#       5 else:
#
# TypeError: '>=' not supported between instances of 'str' and 'int'
