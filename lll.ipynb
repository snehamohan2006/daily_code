# %%
veg=["carrot","onion","tomato","bringjal","drumstick"]
veg.sort()
print(veg)
# Out:
# ['bringjal', 'carrot', 'drumstick', 'onion', 'tomato']

# %%
n=[23,45,12,43,78,2,]
n.sort()
print(n)
# Out:
# [2, 12, 23, 43, 45, 78]

# %%
veg=["carrot","onion","tomato","bringjal","drumstick"]
veg.sort(reverse=True)
print(veg)
# Out:
# ['tomato', 'onion', 'drumstick', 'carrot', 'bringjal']

# %%
def myfunc(n):
    return abs(n-50)
k=[100,23,45,]
k.sort(key=myfunc)
print(k)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       2     return abs(n-50)
#       3 k=["ptato","carrot","drumstick","apple"]
# ----> 4 k.sort(key=myfunc)
#       5 print(k)
#
# Cell In[9], line 2, in myfunc(n)
#       1 def myfunc(n):
# ----> 2     return abs(n-50)
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'
