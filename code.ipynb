# %%
pasword="1234"
use=""
while use!=pasword:
    use=input("enter passwordd:")
print("login succesful")
# Out:
# enter passwordd: 2345
# enter passwordd: 34
# enter passwordd: 567
# enter passwordd: 8907
# enter passwordd: 2345
# enter passwordd: 12345
# enter passwordd: 1234
# login succesful

# %%
i="sneha"
user=""
while user==i:
    user=input("enter i")
    print("yes correct username")
