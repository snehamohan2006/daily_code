# %%
def square(n):
    print(n*n)

square(5)
# Out:
# 25

# %%
def add(a,b):
    print(a+b)

add(10,15)
# Out:
# 25

# %%
def even(n):
    print(n%2==0)

even(1,10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 4
#       1 def even(n):
#       2     print(n%2==0)
# ----> 4 even(1,10)
#
# TypeError: even() takes 1 positional argument but 2 were given
