# %%
class outer:
    def __init__(self):
        self.name="outer class"

    class inner:
        def __init__(self):
            self.name="inner class"

        def __display__(self):
            print("This is the inner class")

outer=outer()
pr
