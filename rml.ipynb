# %%
list=["suma","aksh","mohan"]
list.remove("suma")
print(list)
# Out:
# ['aksh', 'mohan']

# %%
list=["rahul","sachi","messi"]
list.pop(1)
print(list)
# Out:
# ['rahul', 'messi']

# %%
l=["abd","virat","salt","rahul","dhoni"]
l.pop()
print(l)
# Out:
# ['abd', 'virat', 'salt', 'rahul']

# %%
l=["loki","saru","chikku","uddu"]
del l[0]
print(l)
# Out:
# ['saru', 'chikku', 'uddu']

# %%
s=["kavana","spoorthi","suraksha","soudarya"]
s.clear()
print(s)
# Out:
# []

# %%
s=["kavana","spoorthi","suraksha","soudarya"]
del s
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 s=["kavana","spoorthi","suraksha","soudarya"]
#       2 del s
# ----> 3 print(s)
#
# NameError: name 's' is not defined
