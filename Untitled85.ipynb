# %%
class node:
    def __init__(self,data):
        self.data=data
        self.next=None

first=node(10)
second=node(20)
first.next=second
print(head.next.data)
# Out:
# 20

# %%
class Node:
    def __init__(self,data):
        self.data=data
        self.next=None

first=Node(10)
second=Node(20)
third=Node(30)

first.next=second
second.next=third

head=first
print(head.next.data)
print(second.next.data)
print(third.
# Out:
# 20
# 30
