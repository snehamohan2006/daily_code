# %%
age=25
has_licence=True
if age>=18:
    if has_licence:
        print("yes u can drive")
    else:
        print("you need licence")
else:
    print("you need licence to drive")
# Out:
# yes u can drive
