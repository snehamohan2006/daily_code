# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi"}
print(s)
# Out:
# {'lokesh', 'sneha', 'mohan', 'saraswathi', 'suma', 'akshatha'}

# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
print(s)
# Out:
# {True, 2, 'lokesh', 'sneha', 'saraswathi', 'mohan', 'suma', 'akshatha'}

# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
print(len(s))
# Out:
# 8

# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
print(type(s))
# Out:
# <class 'set'>

# %%
t=set(("suma","akshatha","mohan","sneha","lokesh",))
print(t)
# Out:
# {'lokesh', 'sneha', 'mohan', 'suma', 'akshatha'}
