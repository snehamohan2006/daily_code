# %%
fam=["Saraswathi","Lokesh","suma","Akshatha","sneha","Mohan"]
fam.pop()
print(fam)
# Out:
# ['Saraswathi', 'Lokesh', 'suma', 'Akshatha', 'sneha']

# %%
num=[1,2,3,4,5]
num.pop(2)
print(num)
# Out:
# [1, 2, 4, 5]

# %%
num=[2,4,1,7,0,3,10,50,11]
num.sort()
print(num)
# Out:
# [0, 1, 2, 3, 4, 7, 10, 11, 50]
