# %%
i=1
while i<=10:
    if i==5:
        i+=1
        continue
        
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
i=1
while i<=10:
    if i%2==0:
        i+=1
        continue
    print(i)
    i+=1
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i=0
while i<=10:
    i+=1
    if i==5:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10
# 11

# %%
i=1
while i<=10:
    if i%2!=0:
        i+=1
        continue
    print(i)
    i+=1
