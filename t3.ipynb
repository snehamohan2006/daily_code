# %%
def my_func(animal,name):
    print("I have a",animal)
    print("My",animal+" 's name is",name)

my_func(animal="dog",name="Lassi")
# Out:
# I have a dog
# My dog 's name is Lassi

# %%
def my_func(animal,name,age):
    print("I have a",animal,"and its name is",name,"and its",age,"Years old")

my_func(animal="dog",name="lassi",age=16)
# Out:
# I have a dog and its name is lassi and its 16 Years old
