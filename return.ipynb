# %%
def add(a,b):
    return a+b

x=add(5,3)
print(x)
# Out:
# 8

# %%
def add(a,b):
    print(a+b)

add(2,3)
# Out:
# 5

# %%
def square(n):
    return n*n

result=square(10)
print(result)
print(result+1)
# Out:
# 100
# 101

# %%
def calculate(marks):
    total=sum(marks)
    avg=total//len(marks)
    return total,avg
t,avg=calculate([23,34,12,17])

print("Total",t)
print("average",avg)
print("Total+10:",t+10)
# Out:
# Total 86
# average 21
# Total+10: 96
