# %%
class outer:
    def __init__(self):
        self.name="outer class"

    class inner:
        def __init__(self):
            self.name="inner"

        def __display__(self):
            print("This is the inner class")

outer=outer()
inner=outer.inner()
inner.display()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 14
#      12 outer=outer()
#      13 inner=outer.inner()
# ---> 14 inner.display()
#
# AttributeError: 'inner' object has no attribute 'display'
