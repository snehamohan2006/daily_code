# %%
#list is ordered,mutable,allow duplicate values
l=["sneha","mohan","suma"]
print(l)
print(len(l))
print(type(l))
# Out:
# ['sneha', 'mohan', 'suma']
# 3
# <class 'list'>

# %%
list=["santhosh","aishu","kousu","bhavana","rakshitha"]
print(list[-1])
print(list[0])
print(list[1])
print(list[2])
print(list[3])
print(list[2:5])
print(list[1:])
print(list[:-1])
print(list[-4:-1])
# Out:
# rakshitha
# santhosh
# aishu
# kousu
# bhavana
# ['kousu', 'bhavana', 'rakshitha']
# ['aishu', 'kousu', 'bhavana', 'rakshitha']
# ['santhosh', 'aishu', 'kousu', 'bhavana']
# ['aishu', 'kousu', 'bhavana']
