# %%
n=5
i=1
while (i<=10):
    print(n,"x",i,"=",n*i)
    i+=1
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
i=1
while (i<=10):
    if i==5:
        break
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4

# %%
i=0
while (i>=5):
    i+=1
