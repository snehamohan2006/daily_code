# %%
import json
x='{"name":"sneha","age":20,"country":"India"}'
y=json.loads(x)
print(y["age"])
# Out:
# 20

# %%
import json
x={
    "name":"sneha",
    "age":20,
    "country":"india",
    "education":"cse engineering",
}
y=json.dumps(x)
print(y)
# Out:
# {"name": "sneha", "age": 20, "country": "india", "education": "cse engineering"}
