# %%
def green():
    print("hello")

green()
# Out:
# hello

# %%
def say_hello():
    print("Hello Welcome to python")

say_hello()
# Out:
# Hello Welcome to python

# %%
def greet(name):
    print("hello",name)

greet("sneha")
greet("Mohan")
# Out:
# hello sneha
# hello Mohan

# %%
def add(a,b):
    return a+b

result=add(10,20)
print(result)
# Out:
# 30

# %%
def check_even_odd(n):
    if n%2==0:
        print("even")
    else:
        print("odd")

check_even_odd(10)
check_even_odd(8)
# Out:
# even
# even
