# %%
class person:
    lastname=""

    def __init__(self,name):
        self.name=name

p1=person("sneha")
p2=person("Akshatha")

person.lastname="lokesh"

print(p1.lastname)
print(p2.lastname)
# Out:
# lokesh
# lokesh
