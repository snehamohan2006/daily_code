# %%
def my_function(fname):
    print(fname+" Refsnes")

my_function("sneha")
my_function("lovebug")
my_function("suma")
# Out:
# sneha Refsnes
# lovebug Refsnes
# suma Refsnes

# %%
def my_function(name):
    print("hello",name)

my_function("sneha")
# Out:
# hello sneha
