# %%
fam={
    "child1":{
        "name":"suma",
        "age":26
    },
    "child2":{
        "name":"akshatha",
        "age":23
    },
    "child3":{
        "name":"sneha",
        "age":20
    },
    "child4":{
        "name":"mohan",
        "age":17,
    }
}
print(fam)
# Out:
# {'child1': {'name': 'suma', 'age': 26}, 'child2': {'name': 'akshatha', 'age': 23}, 'child3': {'name': 'sneha', 'age': 20}, 'child4': {'name': 'mohan', 'age': 17}}

# %%
child1={
        "name":"suma",
        "age":26
},
child2={
    "name":"akshatha",
    "age":23
},
child3={
    "name":"sneha",
    "age":20
},
child4={
    "name":"mohan",
    "age":17,
}

fam={
    "child1":child1,
    "child2":child2,
    "child3":child3,
    "child4":child4
}
print(fam)
# Out:
# {'child1': ({'name': 'suma', 'age': 26},), 'child2': ({'name': 'akshatha', 'age': 23},), 'child3': ({'name': 'sneha', 'age': 20},), 'child4': {'name': 'mohan', 'age': 17}}

# %%
for x,obj in fam.items():
    print(x)

for y in obj
