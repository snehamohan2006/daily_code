# %%
toys=["car","doll","camera","teddy"]
print(toys)
# Out:
# ['car', 'doll', 'camera', 'teddy']

# %%
print(toys[0])
# Out:
# car

# %%
print(toys[1])
# Out:
# doll

# %%
print(toys[2])
# Out:
# camera

# %%
print(toys[3])
# Out:
# teddy

# %%
toys.append("cap")
print(toys)
# Out:
# ['car', 'doll', 'camera', 'teddy', 'cap', 'cap']

# %%
toys.remove([0])
print(toys)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 toys.remove([0])
#       2 print(toys)
#
# ValueError: list.remove(x): x not in list
