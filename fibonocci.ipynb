# %%
n=int(input("Enter the number:"))
a=0
b=1
if n<=0:
    print("Invalid input")
elif n==1:
    print("it is fibonocci series",a)
elif n==2:
    print("its fibonocci series",b)
else:
    for i in range(3,n+1):
        c=a+b
        a=b
        b=c

    print("fibonocci number",b)
# Out:
# Enter the number: 2
# its fibonocci series 1
