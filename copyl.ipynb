# %%
thislist=["suma","akshatha","sneha","mohan"]
newlist=thislist.copy()
print(newlist)
# Out:
# ['suma', 'akshatha', 'sneha', 'mohan']

# %%
thislist=["suma","akshatha","sneha","mohan"]
mylist=list(thislist)
print(mylist)
# Out:
# ['suma', 'akshatha', 'sneha', 'mohan']

# %%
thislist=["suma","akshatha","sneha","mohan"]
mylist=thislist[:]
print(mylist)
# Out:
# ['suma', 'akshatha', 'sneha', 'mohan']
