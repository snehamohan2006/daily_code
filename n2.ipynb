# %%
print("Enter your name:")
name=input()
print(f"hello {name}")
# Out:
# Enter your name:
#  Sneha
# hello Sneha

# %%
print("Enter your Name:")
name=input()
print(f"Shede {name}")
# Out:
# Enter your Name:
#  sidda
# Shede sidda
