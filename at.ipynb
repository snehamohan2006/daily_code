# %%
tuple=("mohan","sneha","aksh")
print(tuple)
# Out:
# ('mohan', 'sneha', 'aksh')

# %%
tuple=("mohan","sneha","aksh")
print(tuple[1])
# Out:
# sneha

# %%
tuple=("mohan","sneha","aksh")
print(tuple[0])
# Out:
# mohan

# %%
tuple=("mohan","sneha","aksh")
print(tuple[-1])
# Out:
# aksh

# %%
tuple=("mohan","sneha","aksh")
print(tuple[1:2])
# Out:
# ('sneha',)

# %%
tuple=("mohan","sneha","aksh")
print(tuple[1:3])
# Out:
# ('sneha', 'aksh')

# %%
tuple=("mohan","sneha","aksh")
print(tuple[1:])
# Out:
# ('sneha', 'aksh')

# %%
tuple=("mohan","sneha","aksh")
print(tuple[0:])
# Out:
# ('mohan', 'sneha', 'aksh')
