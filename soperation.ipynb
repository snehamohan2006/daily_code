# %%
s={1,2,3,4}
s.add(5)
print(s)
# Out:
# {1, 2, 3, 4, 5}

# %%
s={1,2,3,4}
s.pop()
print(s)
# Out:
# {2, 3, 4}

# %%
s={1,2,3,4}
s.add("sneha")
print(s)
# Out:
# {1, 2, 3, 4, 'sneha'}

# %%
s={1,2,3,4}
trophical={3,4,5,6}
s.update(trophical)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}
