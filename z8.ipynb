# %%
class person:
    def __init__(self,name):
        sel.name=name

    def printname(self):
        print(self.name)

p1=person("sneha")
p2=person("mohan")

p1.printname()
p2.printname()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       5     def printname(self):
#       6         print(self.name)
# ----> 8 p1=person("sneha")
#       9 p2=person("mohan")
#      11 p1.printname()
#
# Cell In[1], line 3, in person.__init__(self, name)
#       2 def __init__(self,name):
# ----> 3     sel.name=name
#
# NameError: name 'sel' is not defined
