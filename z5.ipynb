# %%
def name():
    print("hello",name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 4
#       1 def name():
#       2     print("hello",name)
# ----> 4 name(sneha)
#
# NameError: name 'sneha' is not defined
