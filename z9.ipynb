# %%
class person:
    def __init__(myobj,name,age):
        self.name=name
        self.age=age

    def greet(abc):
        print("hello,my name is" + abc.name)

p1=person("sneha",20)
pl.greet()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 9
#       6     def greet(abc):
#       7         print("hello,my name is" + abc.name)
# ----> 9 p1=person("sneha",20)
#      10 pl.greet()
#
# Cell In[1], line 3, in person.__init__(myobj, name, age)
#       2 def __init__(myobj,name,age):
# ----> 3     self.name=name
#       4     self.age=age
#
# NameError: name 'self' is not defined
