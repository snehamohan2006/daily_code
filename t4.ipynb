# %%
def my_func(person):
    print("Name:",person["Name"])
    print("Age:",person["Age"])

person={"Name":"Sneha","Age":20}
my_func(person)
# Out:
# Name: Sneha
# Age: 20

# %%
def my_func(x,y):
    return x+y

result=my_func(5,3)
my_func(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       2     return x+y
#       4 result=my_func(5,3)
# ----> 5 my_func(result)
#
# TypeError: my_func() missing 1 required positional argument: 'y'
