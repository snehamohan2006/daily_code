# %%
def my_func(name):
    print("My freind",name)

my_func("Harshini")
my_func("Kavana")
my_func("aishu")
# Out:
# My freind Harshini
# My freind Kavana
# My freind aishu

# %%
def my_func(country):
    print("I am from",country)

my_func("India")
my_func("US")
my_func("russia")
# Out:
# I am from India
# I am from US
# I am from russia

# %%
def my_func(country="Norway"):
    print("I am from",country)

my_func("India")
my_func("US")
my_func("russia")
# Out:
# I am from India
# I am from US
# I am from russia
