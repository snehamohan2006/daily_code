# %%
def get_greetings():
    return "hello from a function"

print(get_greetings())
# Out:
# hello from a function

# %%
def get_greetings():
    return "hello from a function"

message=get_greetings()
