# %%
#add list item
list=["spiderman","speed","ronaldo","virat","messi","abd"]
print(list)
list.append("rahul")
print(list)
list.insert(2,"sameer")
print(list)
# Out:
# ['spiderman', 'speed', 'ronaldo', 'virat', 'messi', 'abd']
# ['spiderman', 'speed', 'ronaldo', 'virat', 'messi', 'abd', 'rahul']
# ['spiderman', 'speed', 'sameer', 'ronaldo', 'virat', 'messi', 'abd', 'rahul']

# %%
list=["spiderman","speed","messi"]
map=["rahul","sachin"]
list.extend(map)
print(
