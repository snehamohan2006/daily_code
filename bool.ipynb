# %%
10>9
10==9
10<9
# Out:
# False

# %%
x="hello"
y=15
print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
print(bool("abc"))
print(bool(123))
print(bool["apple","cherry","banana"])
# Out:
# True
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 print(bool("abc"))
#       2 print(bool(123))
# ----> 3 print(bool["apple","cherry","banana"])
#
# TypeError: type 'bool' is not subscriptable
