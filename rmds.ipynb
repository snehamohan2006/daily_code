# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
s.remove(1)
print(s)
# Out:
# {2, 'suma', 'saraswathi', 'sneha', 'mohan', 'lokesh', 'akshatha'}

# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
s.discard(2)
print(s)
# Out:
# {True, 'suma', 'saraswathi', 'sneha', 'mohan', 'lokesh', 'akshatha'}

# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
x=s.pop()
print(x)
print(s)
# Out:
# True
# {2, 'suma', 'saraswathi', 'sneha', 'mohan', 'lokesh', 'akshatha'}

# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
print("suma" in
