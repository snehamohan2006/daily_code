# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
s.add("chikku")
print(s)
# Out:
# {True, 'akshatha', 2, 'suma', 'sneha', 'mohan', 'chikku', 'saraswathi', 'lokesh'}

# %%
s={"suma","akshatha","mohan","sneha","lokesh","saraswathi",True,1,2}
tropical={"uddu","lithiksha","kantha"}
s.update(tropical)
print(s)
# Out:
# {True, 'akshatha', 2, 'suma', 'sneha', 'mohan', 'uddu', 'kantha', 'saraswathi', 'lithiksha', 'lokesh'}
