# %%
day=4
match day:
    case 1:
        print("monday")
    case 2:
        print("tuesday")
    case 3:
        print("wednesday")
    case 4:
        print("Thursday")
    case 5:
        print("Friday")
    case 6:
        print("saturday")
    case 7:
        print("sunday")
# Out:
# Thursday

# %%
day=4
match day:
    case 1:
        print("monday")
    case 2:
        print("tuesday")
    case _:
        print("lo
