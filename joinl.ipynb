# %%
n=["sneha","mohan","aksh"]
l=[1,2,3,4]
p=n+l
print(p)
# Out:
# ['sneha', 'mohan', 'aksh', 1, 2, 3, 4]

# %%
n=["sneha","mohan","aksh"]
l=[1,2,3,4]
for x in l:
    n.append(x)

print(n)
# Out:
# ['sneha', 'mohan', 'aksh', 1, 2, 3, 4]

# %%
n=["sneha","mohan","aksh"]
l=[1,2,3,4]
n.extend(l)
print(n)
# Out:
# ['sneha', 'mohan', 'aksh', 1, 2, 3, 4]

# %%
n=["sneha","mohan","aksh"]
n.extend("1")
print(n)
# Out:
# ['sneha', 'mohan', 'aksh', '1']
