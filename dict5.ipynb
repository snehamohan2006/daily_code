# %%
d={
    "maa":"saru",
    "paa":"loki",
    "sis":"suma",
    "bro":"moha"
}
for x in d:
    print(x)
# Out:
# maa
# paa
# sis
# bro

# %%
d={
    "maa":"saru",
    "paa":"loki",
    "sis":"suma",
    "bro":"moha"
}
for x in d:
    print(d[x])
# Out:
# saru
# loki
# suma
# moha

# %%
d={
    "maa":"saru",
    "paa":"loki",
    "sis":"suma",
    "bro":"moha"
}
for x in d.values():
    print(x)
# Out:
# saru
# loki
# suma
# moha

# %%
d={
    "maa":"saru",
    "paa":"loki",
    "sis":"suma",
    "bro":"moha"
}
for x in d:.keys():
    print(x)
# Out:
#   Cell In[7], line 7
#     for x in d:.keys():
#                ^
# SyntaxError: invalid syntax
