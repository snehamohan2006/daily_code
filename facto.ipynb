# %%
n=int(input("enter a number:"))
fact=1
if n<=0:
    print("factorial number is not defined for factorial number")
else:
    for i in range(1,n+1):
        fact=fact*i

    print("factorial is",fact)
# Out:
# enter a number: 1
# factorial is 1

# %%
n=int(input("Enter a number:"))
fact=1
for i in range(1,n+1):
    fact=fact*i

print("factorial number",fact)
# Out:
# Enter a number: 3
# factorial number 6
