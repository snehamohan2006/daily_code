# %%
dict={
    "name":"sneha",
    "sem":"6th sem",
    "stream":"cse"
}
x=dict["stream"]
y=dict.get("sem")
print(x)
print(y)
# Out:
# cse
# 6th sem

# %%
dict={
    "name":"sneha",
    "sem":"6th sem",
    "stream":"cse"
}
x=dict.keys()
print(x)
# Out:
# dict_keys(['name', 'sem', 'stream'])

# %%
dict={
    "name":"sneha",
    "sem":"6th sem",
    "stream":"cse"
}
x=dict.keys()
print(x)
dict["college"]="dsatm"
print(dict)
# Out:
# dict_keys(['name', 'sem', 'stream'])
# {'name': 'sneha', 'sem': '6th sem', 'stream': 'cse', 'college': 'dsatm'}

# %%
dict={
    "name":"sneha",
    "sem":"6th sem",
    "stream":"cse"
}
x=dict.values()
print(x)
# Out:
# dict_values(['sneha', '6th sem', 'cse'])

# %%
dict={
    "name":"sneha",
    "sem":"6th sem",
    "stream":"cse"
}
x=dict.values()
print(x)

dict["year"]=2027
print(dict)
# Out:
# dict_values(['sneha', '6th sem', 'cse'])
# {'name': 'sneha', 'sem': '6th sem', 'stream': 'cse', 'year': 2027}

# %%
dict={
    "name":"sneha",
    "sem":"6th sem",
    "stream":"cse"
}
x=dict.items()
print(x)
# Out:
# dict_items([('name', 'sneha'), ('sem', '6th sem'), ('stream', 'cse')])

# %%
dict={
    "name":"sneha",
    "sem":"6th sem",
    "stream":"cse"
}
