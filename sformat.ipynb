# %%
age=20
txt=f"Hi I am sneha and  I am {age}"
print(txt)
# Out:
# Hi I am sneha and  I am 20

# %%
price=59
txt=f"the price of the banana is {price} rupees"
print(txt)
# Out:
# the price of the banana is 59 rupees

# %%
price=59
txt=f"the price of the banana is {price:.2f} rupees"
