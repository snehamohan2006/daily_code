# %%
n=int(input("enter a number:"))
sum_divisors=0
for i in range(1,n):
    if n%i==0:
        sum_divisors=sum_divisors+i
if sum==n:
    print("perfect number")
else:
    print("not perfect number")
# Out:
# enter a number: 6
# not perfect number
