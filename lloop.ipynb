# %%
#loop in list
tlist=["sneha","aksh","suma"]
for x in tlist:
    print(x)
# Out:
# sneha
# aksh
# suma

# %%
tlist=["sneha","aksh","suma"]
for i in range(len(tlist)):
    print(tlist[i])
# Out:
# sneha
# aksh
# suma

# %%
l=["mango","banana","apple"]
print(len(l))
# Out:
# 3

# %%
l=["pomogranate","orange","jackfruit"]
i=0
while i<len(l):
    print(l[i])
    i+=1
# Out:
# pomogranate
# orange
# jackfruit

# %%
lem=["sneha","mohan","akshatha"]
[print(
