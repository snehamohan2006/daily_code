# %%
fam={
    "mother":"Saraswathi",
    "Father":"Lokesh",
    "Elder one":"suma",
    "middle one":"Akstha",
    "younger one":"sneha",
    "last one":"Mohan"
}
print(fam)
# Out:
# {'mother': 'Saraswathi', 'Father': 'Lokesh', 'Elder one': 'suma', 'middle one': 'Akstha', 'younger one': 'sneha', 'last one': 'Mohan'}

# %%
fam={
    "mother":"Saraswathi",
    "Father":"Lokesh",
    "Elder one":"suma",
    "middle one":"Akstha",
    "younger one":"sneha",
    "last one":"Mohan"
}
print(fam["Father"])
print(fam[0])
# Out:
# Lokesh
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 10
#       1 fam={
#       2     "mother":"Saraswathi",
#       3     "Father":"Lokesh",
#    (...)
#       7     "last one":"Mohan"
#       8 }
#       9 print(fam["Father"])
# ---> 10 print(fam[0])
#
# KeyError: 0
