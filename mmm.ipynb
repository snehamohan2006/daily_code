# %%
def student_info(name,age=18):
    print("Student Name:",name)
    print("student age:",age)

student_info("sneha")
student_info("sneha",19)
# Out:
# Student Name: sneha
# student age: 18
# Student Name: sneha
# student age: 19

# %%
def cube(n):
    print(n)

cube(4)
# Out:
# 4

# %%
def find_max(a,b):
    print("Enter a:",a)
    print("Enter b:",b)
    if a>b:
        print("a is greater")
    else:
        print("b is greater")
    
find_max(23,56)
# Out:
# Enter a: 23
# Enter b: 56
# b is greater
